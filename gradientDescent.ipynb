# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbankhan/AI_Model_figo/blob/main/gradientDescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, random_state=13, noise=80)

# %%
print(y)
# Out:
# [  7.21786552  16.04609925 -27.83756166 144.36688189]

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
# applying OLS
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
# creating gradient descent class
class myclass:
  def __init__(self, lr, epoch):
    self.m = 100
    self.b = -120
    self.lr = lr
    self.epoch = epoch
  def fit(self, X, y):
    for i in range(self.epoch):
      slope_b = -2 * np.sum((y - self.m*X - self.b))
      slope_m = -2 * np.sum((y -self.m*X - self.b)*(X))
      self.b = self.b - self.lr * slope_b
      self.m = self.m - self.lr * slope_m
      print (self.b)
      print (self.m)

# %%
mycs = myclass(0.001,130)
mycs.fit(X,y)
# Out:
# 27.59079588464807
# 34.10315961203575

# %%
|
