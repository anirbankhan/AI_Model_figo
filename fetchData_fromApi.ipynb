# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbankhan/AI_Model_figo/blob/main/fetchData_fromApi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/account/22480366/rated/movies?language=en-US&page=1&sort_by=created_at.asc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4ZjQwZGNiOWY4NTQxMDdiNjNhMDRjYjgwM2FiM2Y1MiIsIm5iZiI6MTc2MzQ0MjQ4OS43NDQsInN1YiI6IjY5MWJmZjM5NGJjZTViY2FiMjgxYzY1MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.1VSN3_aMDV8zvAYUG0DOTog2KUwFO8jUl4hQkXshjHg"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'results': [], 'total_pages': 0, 'total_results': 0}

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4ZjQwZGNiOWY4NTQxMDdiNjNhMDRjYjgwM2FiM2Y1MiIsIm5iZiI6MTc2MzQ0MjQ4OS43NDQsInN1YiI6IjY5MWJmZjM5NGJjZTViY2FiMjgxYzY1MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.1VSN3_aMDV8zvAYUG0DOTog2KUwFO8jUl4hQkXshjHg"
}

response = requests.get(url, headers=headers)

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/hpXBJxLD2SEf8l2CspmSeiHrBKX.jpg',
#   'genre_ids': [18, 27, 14],
#   'id': 1062722,
#   'original_language': 'en',
#   'original_title': 'Frankenstein',
#   'overview': 'Dr. Victor Frankenstein, a brilliant but egotistical scientist, brings a creature to life in a monstrous experiment that ultimately leads to the undoing of both the creator and his tragic creation.',
#   'popularity': 582.9067,
#   'poster_path': '/g4JtvGlQO7DByTI6frUobqvSL3R.jpg',
#   'release_date': '2025-10-17',
#   'title': 'Frankenstein',
#   'video': False,
#   'vote_average': 7.875,
#   'vote_count': 1424},
#  {'adult': False,
#   'backdrop_path': '/5lQ4euO30sDin5nCifvi0vURFNd.jpg',
#   'genre_ids': [28, 35, 10751],
#   'id': 1248226,
#   'original_language': 'en',
#   'original_title': 'Playdate',
# ...

# %%
# Convert the Dataframe into result

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path             genre_ids       id  \
# 0   False  /hpXBJxLD2SEf8l2CspmSeiHrBKX.jpg          [18, 27, 14]  1062722
# 1   False  /5lQ4euO30sDin5nCifvi0vURFNd.jpg       [28, 35, 10751]  1248226
# 2   False  /zpEWFNqoN8Qg1SzMMHmaGyOBTdW.jpg          [28, 53, 80]  1054867
# 3   False  /7FDVhmCur4LMOfnXMteiSCtsdOb.jpg          [28, 12, 14]  1116465
# 4   False  /ebyxeBh56QNXxSJgTnmz7fXAlwk.jpg         [28, 878, 12]  1242898
# 5   False  /sUoPlzchsCECqpm3ZmDPeL8QKDK.jpg          [28, 12, 27]  1084222
# 6   False  /4frrYwamVG0eXhdMTy3cpNNcCBp.jpg      [28, 18, 80, 53]  1128650
# 7   False  /iZLqwEwUViJdSkGVjePGhxYzbDb.jpg             [878, 53]   755898
# 8   False  /ueiD0fJokAMaHSc9tVBM3WF8385.jpg          [28, 53, 80]  1296504
# 9   False  /xmnqFHhGNYHf5JFy4GSfiIEG0ly.jpg          [80, 28, 18]  1429738
# 10  False  /6zKjoOOb3OZnZuiHtQZn4Kd69Gq.jpg              [27, 53]  1197137
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path        genre_ids       id  \
# 0  False  /hpXBJxLD2SEf8l2CspmSeiHrBKX.jpg     [18, 27, 14]  1062722
# 1  False  /5lQ4euO30sDin5nCifvi0vURFNd.jpg  [28, 35, 10751]  1248226
#
#   original_language original_title  \
# 0                en   Frankenstein
# 1                en       Playdate
#
#                                             overview  popularity  \
# 0  Dr. Victor Frankenstein, a brilliant but egoti...    582.9067
# 1  When out-of-work accountant Brian joins stay-a...    396.6845
#
#                         poster_path release_date         title  video  \
# 0  /g4JtvGlQO7DByTI6frUobqvSL3R.jpg   2025-10-17  Frankenstein  False
# 1  /fGodXWqJkkkbSebPIlxLSygV8GY.jpg   2025-11-05      Playdate  False
#
#    vote_average  vote_count
# 0         7.875        1424
# 1         6.515         172

# %%
df =pd.DataFrame(response.json()['results'])[['id','title','release_date','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                     title release_date  vote_average  vote_count
# 0  1062722              Frankenstein   2025-10-17         7.875        1424
# 1  1248226                  Playdate   2025-11-05         6.515         172
# 2  1054867  One Battle After Another   2025-09-23         7.611        1398
# 3  1116465                  A Legend   2024-07-05         6.142          60
# 4  1242898        Predator: Badlands   2025-11-05         7.356         336

# %%
df = pd.DataFrame()
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={}&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4ZjQwZGNiOWY4NTQxMDdiNjNhMDRjYjgwM2FiM2Y1MiIsIm5iZiI6MTc2MzQ0MjQ4OS43NDQsInN1YiI6IjY5MWJmZjM5NGJjZTViY2FiMjgxYzY1MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.1VSN3_aMDV8zvAYUG0DOTog2KUwFO8jUl4hQkXshjHg"
}



for i in range(1,21):
  response = requests.get(url.format(i), headers=headers)
  dfs = pd.DataFrame(response.json()['results'])[['id','title','release_date','vote_average','vote_count']]
  df = pd.concat([df,dfs],ignore_index=True)

# %%
df.size
# Out:
# 2000

# %%
df.shape
# Out:
# (400, 5)

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
df
# Out:
#           id                     title release_date  vote_average  vote_count
# 0    1062722              Frankenstein   2025-10-17         7.875        1424
# 1    1248226                  Playdate   2025-11-05         6.515         172
# 2    1054867  One Battle After Another   2025-09-23         7.611        1398
# 3    1116465                  A Legend   2024-07-05         6.142          60
# 4    1242898        Predator: Badlands   2025-11-05         7.356         336
# ..       ...                       ...          ...           ...         ...
# 395   396194                     Ennio   2022-02-17         8.307         357
# 396    15845                    A Soap   2006-04-07         5.192          26
# 397    46636              Nanga Parbat   2010-01-14         6.600          60
# 398   835459           Sight: Extended   2023-11-03         6.000          12
# 399  1137245             Three Friends   2024-11-06         6.236         106
#
# [400 rows x 5 columns]

# %%
#convert the dataFrame to csv

# %%
df.to_csv('movie_ratings.csv')
