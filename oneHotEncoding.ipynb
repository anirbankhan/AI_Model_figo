# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbankhan/AI_Model_figo/blob/main/oneHotEncoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('train-data.csv')

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df['Name'].value_counts()
# Out:
# Name
# Mahindra XUV500 W8 2WD                     49
# Maruti Swift VDI                           45
# Maruti Swift Dzire VDI                     34
# Honda City 1.5 S MT                        34
# Maruti Swift VDI BSIV                      31
#                                            ..
# Tata New Safari EX 4x2                      1
# Nissan Terrano XL Plus ICC WT20 SE          1
# Honda Brio 1.2 S Option MT                  1
# Volkswagen Vento Konekt Diesel Highline     1
# Lamborghini Gallardo Coupe                  1
# Name: count, Length: 1876, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 1876

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: count, dtype: int64

# %%
df['Owner_Type'].value_counts()
# Out:
# Owner_Type
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# Name: count, dtype: int64

# %%
# one hot encoding is applied for categorical data ,
# basically for nominal data , where We cant do ordering

# %%
# one hot encoding using pandas

# %%
pd.get_dummies(df, columns=['Fuel_Type', 'Owner_Type'])
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Transmission     Mileage   Engine      Power  Seats  \
# ...

# %%
# k-1 hot encoding

# %%
pd.get_dummies(df, columns=['Fuel_Type', 'Owner_Type'], drop_first=True)
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Transmission     Mileage   Engine      Power  Seats  \
# ...

# %%
# one hot encoding using sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,[1,5,7]],df.iloc[:,-1],test_size=0.2)

# %%
X_train.head()
# Out:
#                                      Name Fuel_Type Owner_Type
# 4914  Mercedes-Benz GLC 220d 4MATIC Style    Diesel      First
# 4019          Hyundai i20 Sportz 1.4 CRDi    Diesel     Second
# 735                Maruti Baleno Zeta 1.3    Diesel      First
# 824                      Renault KWID RXT    Petrol      First
# 5686        Mercedes-Benz E-Class 280 CDI    Diesel      First

# %%
X_test.head()
# Out:
#                                        Name Fuel_Type Owner_Type
# 301   Volkswagen Polo Petrol Trendline 1.2L    Petrol      First
# 5597                       Hyundai i10 Asta    Petrol      First
# 4493                BMW 5 Series 530i Sedan    Petrol      First
# 935          Renault Duster 85PS Diesel RxL    Diesel      First
# 1573                  Maruti Ertiga VXI CNG       CNG      First

# %%
y_train.head()
# Out:
# 4914    46.95
# 4019     3.90
# 735      7.83
# 824      3.15
# 5686    11.00
# Name: Price, dtype: float64

# %%
y_test.head()
# Out:
# 301     3.89
# 5597    3.75
# 4493    8.75
# 935     5.75
# 1573    8.35
# Name: Price, dtype: float64

# %%
import numpy as np
ohe = OneHotEncoder(drop='first', sparse_output=False, dtype=np.int32)

# %%
X_train = ohe.fit_transform(X_train[['Fuel_Type']])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipython-input-756239622.py in <cell line: 0>()
# ----> 1 X_train = ohe.fit_transform(X_train[['Fuel_Type']])
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_index.py in __getitem__(self, key)
#      28     """
#      29     def __getitem__(self, key):
# ---> 30         index, new_shape = self._validate_indices(key)
#      31
#      32         # 1D array
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_index.py in _validate_indices(self, key)
#     286             else:  # dense array
#     287                 N = self._shape[index_ndim]
# --> 288                 idx = self._asindices(idx, N)
#     289                 index.append(idx)
#     290                 array_indices.append(index_ndim)
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_index.py in _asindices(self, idx, length)
#     328
# ...

# %%
X_train.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3568005288.py in <cell line: 0>()
# ----> 1 X_train.dtype()
#
# TypeError: 'numpy.dtypes.Float64DType' object is not callable
