# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbankhan/AI_Model_figo/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.ambitionbox.com/list-of-companies?page=1"
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0"
headers = {
    "User-Agent": user_agent
}
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers=headers).text
soup = BeautifulSoup(webpage, 'lxml')
print (soup.prettify())
soup.find_all('h2')[1].text
for i in soup.find_all('h2'):
    companies = i.text.strip()
    print (companies)
