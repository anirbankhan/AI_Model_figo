# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbankhan/AI_Model_figo/blob/main/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('tested.csv',index_col='PassengerId')

# %%
df.size
# Out:
# 4598

# %%
df.shape
# Out:
# (418, 11)

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
# To get the top 5 rows

# %%
df.head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                 Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892            male  34.5      0      0   330911   7.8292   NaN        Q
# 893          female  47.0      1      0   363272   7.0000   NaN        S
# 894            male  62.0      0      0   240276   9.6875   NaN        Q
# 895            male  27.0      0      0   315154   8.6625   NaN        S
# 896          female  22.0      1      1  3101298  12.2875   NaN        S

# %%
# To Get random 5 data

# %%
df.sample(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1205                1       3
# 924                 1       3
# 909                 0       3
# 1251                1       3
# 1099                0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1205                                       Carr, Miss. Jeannie  female  37.0
# 924                   Dean, Mrs. Bertram (Eva Georgetta Light)  female  33.0
# 909                                          Assaf, Mr. Gerios    male  21.0
# 1251         Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...  female  30.0
# 1099                              Collett, Mr. Sidney C Stuart    male  24.0
#
#              SibSp  Parch     Ticket    Fare Cabin Embarked
# PassengerId
# 1205             0      0     368364   7.750   NaN        Q
# 924              1      2  C.A. 2315  20.575   NaN        S
# 909              0      0       2692   7.225   NaN        C
# ...

# %%
# Get the data about the column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 892 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Name      418 non-null    object
#  3   Sex       418 non-null    object
#  4   Age       332 non-null    float64
#  5   SibSp     418 non-null    int64
#  6   Parch     418 non-null    int64
#  7   Ticket    418 non-null    object
#  8   Fare      417 non-null    float64
#  9   Cabin     91 non-null     object
#  10  Embarked  418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 39.2+ KB

# %%
# To check the number of missing values in each column

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
# to get the insight of the data , It will show the insight for numerical data only

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean     0.363636    2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.481622    0.841838   14.181209    0.896760    0.981429   55.907576
# min      0.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   39.000000    1.000000    0.000000   31.500000
# max      1.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
# To check Total number of rows of duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# how is the co-relation between columns , It will be applicable for numeric columns only

# %%
columns_to_ignore = ['Name','Sex','Ticket','Cabin','Embarked']
df_for_corelations = df.drop(columns = columns_to_ignore)
df_for_corelations.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.108615 -0.000013  0.099943  0.159120  0.191514
# Pclass   -0.108615  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age      -0.000013 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# SibSp     0.099943  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch     0.159120  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare      0.191514 -0.577147  0.337932  0.171539  0.230046  1.000000

# %%
df.head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                 Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892            male  34.5      0      0   330911   7.8292   NaN        Q
# 893          female  47.0      1      0   363272   7.0000   NaN        S
# 894            male  62.0      0      0   240276   9.6875   NaN        Q
# 895            male  27.0      0      0   315154   8.6625   NaN        S
# 896          female  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_for_corelations.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 892                 0       3  34.5      0      0   7.8292
# 893                 1       3  47.0      1      0   7.0000
# 894                 0       2  62.0      0      0   9.6875
# 895                 0       3  27.0      0      0   8.6625
# 896                 1       3  22.0      1      1  12.2875
