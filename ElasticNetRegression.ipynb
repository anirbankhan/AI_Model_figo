# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbankhan/AI_Model_figo/blob/main/ElasticNetRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#Linear Regression
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.4399338661568968

# %%
#Ridge Regression
ridge  = Ridge(alpha=0.1)
ridge.fit(X_train,y_train)
y_pred = ridge.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.45199494197195456

# %%
#Ridge Regression
ls  = Lasso(alpha=0.1)
ls.fit(X_train,y_train)
y_pred = ls.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.4334618007658305

# %%
#ElasticNet Regression
en  = ElasticNet(alpha=0.01,l1_ratio=0.9)
en.fit(X_train,y_train)
y_pred = en.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.4477983324130236
